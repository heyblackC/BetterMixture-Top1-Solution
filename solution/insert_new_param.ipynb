# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

import os
import json


# 读取json文件
# deberta reward model score
with open('./socre_deberta_0130_list.jsonl', "r", encoding="utf-8") as file:
    score_file = file.readlines()
    score_lines = [float(line.strip().strip("[").strip("]")) for line in score_file]
    
with open('./qwen_1p8_instag.jsonl', "r", encoding="utf-8") as file:
    tag_file_list = file.readlines()

with open("../hallucination_0201_full_40w.jsonl", 'r', encoding="utf-8") as file:
    hallu_score_lines = file.readlines()
    hallu_score_lines = [float(score) for score in hallu_score_lines]

with open("../socre_rerank_0201_list.jsonl", 'r', encoding="utf-8") as file:
    rank_score_lines = file.readlines()
    rank_score_lines = [float(score) for score in rank_score_lines]

with open("./socre_garbage_0205_list.jsonl", 'r', encoding="utf-8") as file:
    garbage_score_lines = file.readlines()
    garbage_score_lines = [json.loads(score) for score in garbage_score_lines]

# mixture/dj_mixture_challenge/deita_quality_40w/mixture_raw_reweight_task_type.json
with open("../deita_quality_40w/mixture_raw_reweight_task_type.json", "r",  encoding="utf-8") as file:
    deita_scores = json.load(file)
    
# /mnt/workspace/mixture/dj_mixture_challenge/output/sft_data/mixture_raw_reweight.jsonl
file1_path = '../output/sft_data/mixture_raw_reweight_task_type.jsonl'
output_path = '../output/sft_data/mixture_raw_reweight_task_type_add_new_tag_score.jsonl'

assert len(score_lines) == len(tag_file_list) == len(hallu_score_lines) == len(rank_score_lines)

import numpy as np
np.random.seed(42)
print_cnt = 200

score_cnt = 0
with open(file1_path, 'r') as file1 , open(output_path, 'w', encoding='utf-8') as outfile:
    # 使用zip_longest从两个文件中交替读取行，直到两个文件都读完
    # 如果其中一个文件比另一个长，它将继续读取，另一个文件的位置用None填充
    lines_ = file1.readlines()
    print(len(lines_))
    
    for idx, line in enumerate(lines_):
        cur_data = json.loads(line)
        
        
        cur_data["instag"] = tag_file_list[idx]
        score = score_lines[idx]
        cur_data["reward"] = score
        cur_data["deita_quality"] = deita_scores[idx]
        
        cur_data["hallucination"] = hallu_score_lines[idx]
        
        cur_data["rerank"] = rank_score_lines[idx]
        
        # if garbage_score_lines[idx][1] > 0.9:
        #     print(cur_data)
            
        
        outfile.write(json.dumps(cur_data, ensure_ascii=False) + '\n')
print(score_cnt)
# Out:
# 458941
# 0

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

import os
import json


# 读取json文件
# deberta reward model score
with open('./socre_deberta_0130_list.jsonl', "r", encoding="utf-8") as file:
    score_file = file.readlines()
    score_lines = [float(line.strip().strip("[").strip("]")) for line in score_file]
    
with open('./qwen_1p8_instag.jsonl', "r", encoding="utf-8") as file:
    tag_file_list = file.readlines()

with open("../hallucination_0201_full_40w.jsonl", 'r', encoding="utf-8") as file:
    hallu_score_lines = file.readlines()
    hallu_score_lines = [float(score) for score in hallu_score_lines]

with open("../socre_rerank_0201_list.jsonl", 'r', encoding="utf-8") as file:
    rank_score_lines = file.readlines()
    rank_score_lines = [float(score) for score in rank_score_lines]

with open("./socre_garbage_0205_list.jsonl", 'r', encoding="utf-8") as file:
    garbage_score_lines = file.readlines()
    garbage_score_lines = [json.loads(score) for score in garbage_score_lines]

print(len(garbage_score_lines))
# mixture/dj_mixture_challenge/deita_quality_40w/mixture_raw_reweight_task_type.json
with open("../deita_quality_40w/mixture_raw_reweight_task_type.json", "r",  encoding="utf-8") as file:
    deita_scores = json.load(file)
    
# /mnt/workspace/mixture/dj_mixture_challenge/output/sft_data/mixture_raw_reweight.jsonl
file1_path = '../output/sft_data/mixture_raw_reweight_task_type.jsonl'
output_path = '../output/sft_data/mixture_raw_reweight_task_type_add_new_tag_score.jsonl'

assert len(score_lines) == len(tag_file_list) == len(hallu_score_lines) == len(rank_score_lines)

import numpy as np
np.random.seed(42)
print_cnt = 100

score_cnt = 0
end_sign_cnt = 0
ghost_cnt=0

outfile_tmp = open("tmp_output.jsonl", 'w', encoding='utf-8')
    
generate_nonsense_count = 0
with open(file1_path, 'r') as file1:
    # 使用zip_longest从两个文件中交替读取行，直到两个文件都读完
    # 如果其中一个文件比另一个长，它将继续读取，另一个文件的位置用None填充
    lines_ = file1.readlines()
    print(len(lines_))
    
    for idx, line in enumerate(lines_):
        cur_data = json.loads(line)
        
        
        cur_data["instag"] = tag_file_list[idx]
        score = score_lines[idx]
        cur_data["reward"] = score
        cur_data["deita_quality"] = deita_scores[idx]
        
        cur_data["hallucination"] = hallu_score_lines[idx]
        
        cur_data["rerank"] = rank_score_lines[idx]
        
        if "</s> " in  cur_data["text"]:
            end_sign_cnt += 1
        if "ghost" in cur_data["text"]:
            # if print_cnt:
            #     print_cnt -= 1
            #     print(cur_data)
            ghost_cnt += 1
            
        if garbage_score_lines[idx][1] > 0.9:
            if print_cnt:
                print_cnt -= 1
                print(cur_data)
            
        # if "descriptive writing" in cur_data["instag"] or \
        #     "scene description" in cur_data["instag"] or \
        #     "set description" in cur_data["instag"] or \
        #     "character development" in cur_data["instag"] or \
        #     "plot development" in cur_data["instag"]:
        # if "imagery" in cur_data["instag"] or \
        #     "imagination" in cur_data["instag"] or \
        #     "fantasy" in cur_data["instag"]:
        # fiction write 
        # storytelling
        # ["编故事", "写作风格", "角色扮演", "解释", "故事续写"
        
        # role-playing
        # if topic_prob[0] > 0.40
        # if any(item in cur_data["topic_label"][:1] for item in ["编故事", "角色扮演", "故事续写"]):

            generate_nonsense_count += 1
            outfile_tmp.write(json.dumps(cur_data, ensure_ascii=False) + '\n')
print("end_sign_cnt",end_sign_cnt)
print("ghost_cnt",ghost_cnt)
print("generate_nonsense_count",generate_nonsense_count)
# Out:
# 458941
# 458941
# {'instruction': 'What is the exponential form of the equation y = 3x + 5?', 'input': '', 'output': 'There is no exponential form of the linear equation y = 3x + 5.', 'text': 'What is the exponential form of the equation y = 3x + 5?  There is no exponential form of the linear equation y = 3x + 5.', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.882503867149353, 'line_break_cnt': 0, 'o_i_ratio': 1.125, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': True, 'qa_pair': False, 'topic_label': ['算法', '数学计算', '多选题', '对比分析', '定义解释', '关系判断', '解释', '句法分析', '格式输出', '完形填空'], 'topic_prob': [0.4654199481010437, 0.42805492877960205, 0.42317989468574524, 0.40002527832984924, 0.39049166440963745, 0.390460342168808, 0.3880157768726349, 0.38692885637283325, 0.38646841049194336, 0.3855116665363312], 'instag': '["mathematics", "equation", "exponent", "algebra"]\n', 'reward': 0.5054382085800171, 'deita_quality': 1.9866783494344418, 'hallucination': 0.03389995917677879, 'rerank': 0.6690600514411926}
# {'instruction': "Orange crush hopes Damien Rhodes scored on a 2-yard run in the second overtime, then Syracuse's defense stopped Pittsburgh on fourth and 1, sending the Orange to a 38-31 victory yesterday in Syracuse, N.Y. \nIs this a piece of news regarding world politics, sports, business, or science and technology? ", 'input': '', 'output': 'sports', 'text': "Orange crush hopes Damien Rhodes scored on a 2-yard run in the second overtime, then Syracuse's defense stopped Pittsburgh on fourth and 1, sending the Orange to a 38-31 victory yesterday in Syracuse, N.Y. \nIs this a piece of news regarding world politics, sports, business, or science and technology?   sports", 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.023962080478668213, 'line_break_cnt': 1, 'o_i_ratio': 0.02, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['新闻总结', '总结摘要', '摘要生成', '对比分析', '多选题', '数据分析', '句法分析', '写作风格', '科学、技术、工程和数学STEM', '标题生成'], 'topic_prob': [0.39293336868286133, 0.3745884895324707, 0.3641086220741272, 0.36272943019866943, 0.33048197627067566, 0.3236660063266754, 0.3228412866592407, 0.3186773955821991, 0.3175966739654541, 0.31666693091392517], 'instag': '["sport news"]\n', 'reward': -2.268486499786377, 'deita_quality': 2.1456120780912897, 'hallucination': 0.9975647926330566, 'rerank': 0.4598287343978882}
# {'instruction': 'Big East Picks Syracuse Hoops in Preseason Syracuse was the runaway preseason pick of Big East coaches Wednesday on the strength of a team that has all its starters back after reaching the round of 16 last season. \nIs this a piece of news regarding world politics, sports, business, or science and technology? ', 'input': '', 'output': 'sports', 'text': 'Big East Picks Syracuse Hoops in Preseason Syracuse was the runaway preseason pick of Big East coaches Wednesday on the strength of a team that has all its starters back after reaching the round of 16 last season. \nIs this a piece of news regarding world politics, sports, business, or science and technology?   sports', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.009156824089586735, 'line_break_cnt': 1, 'o_i_ratio': 0.019, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['新闻总结', '相似推荐', '总结摘要', '对比分析', '多选题', '任务规划', '关键词提取', '摘要生成', '解释', '意图分类'], 'topic_prob': [0.37306904792785645, 0.3546622395515442, 0.33374547958374023, 0.3229888379573822, 0.30359265208244324, 0.303139328956604, 0.303083211183548, 0.29690811038017273, 0.29568344354629517, 0.2934969663619995], 'instag': '["sport news"]\n', 'reward': -1.991835117340088, 'deita_quality': 2.1594734968493867, 'hallucination': 0.9250026941299438, 'rerank': 0.44367289543151855}
# {'instruction': 'Write a warm scene inside of a medieval kitchen with a pot, coal scuttle, storage cabinet, bread, and stove.', 'input': '', 'output': 'The fire crackled merrily in the stove, casting a warm glow over the small kitchen. A pot bubbled away on top, the aroma of savory broth filling the air. The coal scuttle sat in the corner, ready to be used if the fire needed a little extra help. A tall storage cabinet stood against one wall, filled with all manner of ingredients and utensils. A crusty loaf of bread sat on a nearby table, begging to be sliced and slathered with butter. Despite the chill in the air outside, the kitchen felt cozy and inviting, the perfect place to spend a chilly afternoon. ', 'text': 'Write a warm scene inside of a medieval kitchen with a pot, coal scuttle, storage cabinet, bread, and stove.  The fire crackled merrily in the stove, casting a warm glow over the small kitchen. A pot bubbled away on top, the aroma of savory broth filling the air. The coal scuttle sat in the corner, ready to be used if the fire needed a little extra help. A tall storage cabinet stood against one wall, filled with all manner of ingredients and utensils. A crusty loaf of bread sat on a nearby table, begging to be sliced and slathered with butter. Despite the chill in the air outside, the kitchen felt cozy and inviting, the perfect place to spend a chilly afternoon. ', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.07348576188087463, 'line_break_cnt': 0, 'o_i_ratio': 5.194, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['写作风格', '句子改写', '文本扩写', '文章写作', '文本蕴含', '完形填空', '格式输出', '创造性写作', '故事续写', '摘要生成'], 'topic_prob': [0.4284939765930176, 0.39667612314224243, 0.38048696517944336, 0.3780211806297302, 0.3771394193172455, 0.37459486722946167, 0.37186115980148315, 0.3703165352344513, 0.3701964020729065, 0.3622267544269562], 'instag': '["creative writing", "set description", "character description", "food preparation", "imagination"]\n', 'reward': 2.760828971862793, 'deita_quality': 4.037164671011851, 'hallucination': 0.020381102338433266, 'rerank': 0.7880820035934448}
# {'instruction': 'Olson Collects 1,000th Win Arizona coach Lute Olson gets his 1,000th victory Saturday as the No. 15 Wildcats knock off visiting Utah, 67-62, in Tuscon. \nIs this a piece of news regarding world politics, sports, business, or science and technology? ', 'input': '', 'output': 'sports', 'text': 'Olson Collects 1,000th Win Arizona coach Lute Olson gets his 1,000th victory Saturday as the No. 15 Wildcats knock off visiting Utah, 67-62, in Tuscon. \nIs this a piece of news regarding world politics, sports, business, or science and technology?   sports', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.003523151623085141, 'line_break_cnt': 1, 'o_i_ratio': 0.024, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['新闻总结', '总结摘要', '写作风格', '多选题', '多语言问答', '摘要生成', '对比分析', '数据分析', '信息抽取', '关键词提取'], 'topic_prob': [0.4141313135623932, 0.36123448610305786, 0.33659857511520386, 0.3350870907306671, 0.32695087790489197, 0.3232121169567108, 0.32010218501091003, 0.31615370512008667, 0.31395041942596436, 0.31383830308914185], 'instag': '["sport news"]\n', 'reward': -1.1374987363815308, 'deita_quality': 2.2299074090105933, 'hallucination': 0.9971452355384827, 'rerank': 0.4441167116165161}
# {'instruction': 'What is the most recent research on erectile dysfunction?', 'input': '', 'output': 'There have been several recent studies investigating the causes and treatments of erectile dysfunction. One study found that a Mediterranean diet could improve erectile function in men with metabolic syndrome. Another study found that treatment with low-intensity shockwave therapy may be effective in treating mild to moderate erectile dysfunction. Overall, research suggests that lifestyle changes such as exercise and a healthy diet, as well as medical treatments like phosphodiesterase type 5 inhibitors, may be effective in improving erectile function.', 'text': 'What is the most recent research on erectile dysfunction?  There have been several recent studies investigating the causes and treatments of erectile dysfunction. One study found that a Mediterranean diet could improve erectile function in men with metabolic syndrome. Another study found that treatment with low-intensity shockwave therapy may be effective in treating mild to moderate erectile dysfunction. Overall, research suggests that lifestyle changes such as exercise and a healthy diet, as well as medical treatments like phosphodiesterase type 5 inhibitors, may be effective in improving erectile function.', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.12052832543849945, 'line_break_cnt': 0, 'o_i_ratio': 9.772, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': True, 'qa_pair': False, 'topic_label': ['自然语言推理', '对比分析', '科学、技术、工程和数学STEM', '算法', '产品推荐', '多语言问答', '相似推荐', '新闻总结', '数据处理', '句法分析'], 'topic_prob': [0.2699059844017029, 0.2595711648464203, 0.2575814127922058, 0.2563437223434448, 0.2555757462978363, 0.23853358626365662, 0.23811252415180206, 0.2368156462907791, 0.22829961776733398, 0.22740520536899567], 'instag': '["information request"]\n', 'reward': 3.514864206314087, 'deita_quality': 4.134132951340689, 'hallucination': 0.5425214767456055, 'rerank': 0.6384066343307495}
# {'instruction': 'What label best describes this news article?\nStill awaiting Microsoft #39;s search entry Microsoft is expected to launch a beta version of its Web search technology on Thursday, with ambitions to catch up to rivals Google and Yahoo. ', 'input': '', 'output': 'Technology', 'text': 'What label best describes this news article?\nStill awaiting Microsoft #39;s search entry Microsoft is expected to launch a beta version of its Web search technology on Thursday, with ambitions to catch up to rivals Google and Yahoo.   Technology', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.02385229431092739, 'line_break_cnt': 1, 'o_i_ratio': 0.043, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': True, 'qa_pair': False, 'topic_label': ['信息检索', '文本检索', '新闻总结', '软件开发', '关键词提取', '社交媒体', '网页开发', '标题生成', '编程语言', '算法'], 'topic_prob': [0.49918127059936523, 0.4836573302745819, 0.4297230541706085, 0.4240982234477997, 0.42206481099128723, 0.41841962933540344, 0.41814494132995605, 0.41169267892837524, 0.4071037173271179, 0.40151268243789673], 'instag': '["information request"]\n', 'reward': -2.425377368927002, 'deita_quality': 2.1278017443287354, 'hallucination': 0.23292163014411926, 'rerank': 0.42226651310920715}
# {'instruction': 'EBay closes in on South Korean auction house EBay looks set to complete the purchase of an online auction business in South Korea. On Thursday it filed a tender offer to acquire the remaining shares of Internet Auction (IAC) that it does not already own, in a deal valued at about \\$4m (2. \nIs this a piece of news regarding world politics, sports, business, or science and technology? ', 'input': '', 'output': 'business', 'text': 'EBay closes in on South Korean auction house EBay looks set to complete the purchase of an online auction business in South Korea. On Thursday it filed a tender offer to acquire the remaining shares of Internet Auction (IAC) that it does not already own, in a deal valued at about \\$4m (2. \nIs this a piece of news regarding world politics, sports, business, or science and technology?   business', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.0007140300585888326, 'line_break_cnt': 1, 'o_i_ratio': 0.021, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['信息检索', '新闻总结', '关键词提取', '解释', '多语言问答', '关系判断', '完形填空', '标题生成', '对比分析', '问答系统'], 'topic_prob': [0.4287879467010498, 0.4169946312904358, 0.4086676239967346, 0.40702760219573975, 0.4067177474498749, 0.4051632285118103, 0.40017738938331604, 0.3925795555114746, 0.39136648178100586, 0.39065805077552795], 'instag': '["business news"]\n', 'reward': -1.8742684125900269, 'deita_quality': 2.3842009232685086, 'hallucination': 0.9028485417366028, 'rerank': 0.36642447113990784}
# {'instruction': 'Sports briefs November 12, 2004 The final cost of the Athens Olympics soared to about \\$11.6 billion -- at least \\$3.1 billion more than originally estimated. The figure did not include transportation projects such as the new tram line, suburban  \nIs this a piece of news regarding world politics, sports, business, or science and technology? ', 'input': '', 'output': 'sports', 'text': 'Sports briefs November 12, 2004 The final cost of the Athens Olympics soared to about \\$11.6 billion -- at least \\$3.1 billion more than originally estimated. The figure did not include transportation projects such as the new tram line, suburban  \nIs this a piece of news regarding world politics, sports, business, or science and technology?   sports', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.02799670770764351, 'line_break_cnt': 1, 'o_i_ratio': 0.017, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['新闻总结', '总结摘要', '算法', '对比分析', '信息检索', '标题生成', '多选题', '社交媒体', '摘要生成', '句子改写'], 'topic_prob': [0.45017027854919434, 0.3520843982696533, 0.35138392448425293, 0.3332521617412567, 0.32522517442703247, 0.32188713550567627, 0.3202363848686218, 0.31640180945396423, 0.31544458866119385, 0.31502771377563477], 'instag': '["sport news"]\n', 'reward': -1.9698522090911865, 'deita_quality': 2.02139355059262, 'hallucination': 0.9982061386108398, 'rerank': 0.4509132504463196}
# {'instruction': 'Utah a Clean Air Act offender, study says A new national study identifies Utah as one of at least 29 states that have loopholes in their laws allowing for  quot;accidental quot; pollution emissions beyond the limits of the federal Clean Air Act. \nIs this a piece of news regarding world politics, sports, business, or science and technology? ', 'input': '', 'output': 'science and technology', 'text': 'Utah a Clean Air Act offender, study says A new national study identifies Utah as one of at least 29 states that have loopholes in their laws allowing for  quot;accidental quot; pollution emissions beyond the limits of the federal Clean Air Act. \nIs this a piece of news regarding world politics, sports, business, or science and technology?   science and technology', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.1278776377439499, 'line_break_cnt': 1, 'o_i_ratio': 0.064, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['新闻总结', '定义解释', '解释', '句法分析', '总结摘要', '指代消解', '对比分析', '意见参考', '阅读理解', '信息检索'], 'topic_prob': [0.4472546875476837, 0.426497220993042, 0.415702760219574, 0.4084005653858185, 0.37448298931121826, 0.37125396728515625, 0.3630635440349579, 0.35536959767341614, 0.3483757972717285, 0.34634894132614136], 'instag': '["science and technology"]\n', 'reward': -2.239611864089966, 'deita_quality': 2.308129095705226, 'hallucination': 0.8417490720748901, 'rerank': 0.49570584297180176}
# {'instruction': 'Generate for a joyful scene outside of a coastal dock with families and birds.', 'input': '', 'output': "The coastal dock is bustling with families enjoying the sunny day. Children laugh and play near the water's edge while their parents set up picnic blankets and beach chairs. Seagulls circle above, their calls echoing in the salty air. A group of pelicans perched on a piling watch as a fishing boat slowly makes its way out to sea. The water is a deep blue-green, sparkling in the sunlight. It's a perfect day for a day at the dock!", 'text': "Generate for a joyful scene outside of a coastal dock with families and birds.  The coastal dock is bustling with families enjoying the sunny day. Children laugh and play near the water's edge while their parents set up picnic blankets and beach chairs. Seagulls circle above, their calls echoing in the salty air. A group of pelicans perched on a piling watch as a fishing boat slowly makes its way out to sea. The water is a deep blue-green, sparkling in the sunlight. It's a perfect day for a day at the dock!", 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.08955339342355728, 'line_break_cnt': 0, 'o_i_ratio': 5.538, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['编故事', '解释', '摘要生成', '定义解释', '完形填空', '内容创作', '意图分类', '多选题', '文本生成', '指代消解'], 'topic_prob': [0.40211251378059387, 0.3987077474594116, 0.36834245920181274, 0.35520675778388977, 0.35383039712905884, 0.35021305084228516, 0.35007134079933167, 0.35006555914878845, 0.34944719076156616, 0.3488933742046356], 'instag': '["scene description", "set", "family", "nature"]\n', 'reward': 1.94132661819458, 'deita_quality': 3.14329634015985, 'hallucination': 0.7248591780662537, 'rerank': 0.7285362482070923}
# {'instruction': 'Please generate an enchanting scene outside a farmland field with kites, a tent, rope, and silk.', 'input': '', 'output': 'As the sun sets behind the farmland field, a colorful array of kites can be seen flying high in the sky. A luxurious silk tent has been set up with ropes securing it to nearby trees. The gentle breeze carries the sounds of laughter and conversations from within the tent, where people are gathered to enjoy the scenic views from outside. A group of children playfully run around, flying their kites and waving at the people inside the tent. The whole scene is illuminated with a golden glow and fills the heart with warmth and joy.', 'text': 'Please generate an enchanting scene outside a farmland field with kites, a tent, rope, and silk.  As the sun sets behind the farmland field, a colorful array of kites can be seen flying high in the sky. A luxurious silk tent has been set up with ropes securing it to nearby trees. The gentle breeze carries the sounds of laughter and conversations from within the tent, where people are gathered to enjoy the scenic views from outside. A group of children playfully run around, flying their kites and waving at the people inside the tent. The whole scene is illuminated with a golden glow and fills the heart with warmth and joy.', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.08194045722484589, 'line_break_cnt': 0, 'o_i_ratio': 5.531, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['编故事', '完形填空', '句子改写', '摘要生成', '文本生成', '标签生成', '解释', '多选题', '表格生成', '格式输出'], 'topic_prob': [0.4212779104709625, 0.4026336967945099, 0.3915066719055176, 0.38776659965515137, 0.3848685622215271, 0.37240204215049744, 0.3709019422531128, 0.3707852363586426, 0.36991143226623535, 0.3654709756374359], 'instag': '["scene description", "set", "character", "material"]\n', 'reward': 0.8720115423202515, 'deita_quality': 5.085022033956193, 'hallucination': 0.004915212281048298, 'rerank': 0.7714482545852661}
# {'instruction': 'Is this a piece of news regarding world politics, sports, business, or science and technology?\nU.S. Oil Clings Near  #36;47 (Reuters) Reuters - U.S. oil prices hovered near  #36;47 a\\barrel on Wednesday, awaiting data that was expected to show a\\big drop in fuel stocks in the United States due to\\weather-related disruptions to output and shipments. \n', 'input': '', 'output': 'This is a piece of news regarding business.', 'text': 'Is this a piece of news regarding world politics, sports, business, or science and technology?\nU.S. Oil Clings Near  #36;47 (Reuters) Reuters - U.S. oil prices hovered near  #36;47 a\\barrel on Wednesday, awaiting data that was expected to show a\\big drop in fuel stocks in the United States due to\\weather-related disruptions to output and shipments. \n  This is a piece of news regarding business.', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.020209625363349915, 'line_break_cnt': 2, 'o_i_ratio': 0.122, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['新闻总结', '数据分析', '信息检索', '科学、技术、工程和数学STEM', '数据处理', '数据操作', '标题生成', '信息查询', '社交媒体', '对比分析'], 'topic_prob': [0.4559457302093506, 0.3932080864906311, 0.3839294910430908, 0.38189709186553955, 0.3725060224533081, 0.37237799167633057, 0.3686296045780182, 0.3648005425930023, 0.36320003867149353, 0.36201295256614685], 'instag': '["news inquiry"]\n', 'reward': -1.4213833808898926, 'deita_quality': 2.145057629848452, 'hallucination': 0.1232483759522438, 'rerank': 0.5730370879173279}
# {'instruction': 'Office Depot cuts profit forecast Office Depot Inc. warned Tuesday of weaker-than-expected profits for the rest of the year because of disruptions from the string of hurricanes in Florida and poor sales in the rest of North America and in Europe. \nIs this a piece of news regarding world politics, sports, business, or science and technology? ', 'input': '', 'output': 'business', 'text': 'Office Depot cuts profit forecast Office Depot Inc. warned Tuesday of weaker-than-expected profits for the rest of the year because of disruptions from the string of hurricanes in Florida and poor sales in the rest of North America and in Europe. \nIs this a piece of news regarding world politics, sports, business, or science and technology?   business', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.009449285455048084, 'line_break_cnt': 1, 'o_i_ratio': 0.023, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['新闻总结', '总结摘要', '关键词提取', '信息检索', '摘要生成', '市场策略', '信息抽取', '错误处理', '解释', '对比分析'], 'topic_prob': [0.4539839029312134, 0.4283623993396759, 0.42023783922195435, 0.4153802990913391, 0.40133336186408997, 0.39680418372154236, 0.3960500955581665, 0.39570558071136475, 0.38951921463012695, 0.3876311480998993], 'instag': '["business news"]\n', 'reward': -0.9205528497695923, 'deita_quality': 2.484158471531373, 'hallucination': 0.9229732155799866, 'rerank': 0.3675804138183594}
# {'instruction': "Out in Japan: High-Def Home Movies Sony's first consumer HD camcorder is expected to arrive in the U.S. soon. \nIs this a piece of news regarding world politics, sports, business, or science and technology? ", 'input': '', 'output': 'Science and technology.', 'text': "Out in Japan: High-Def Home Movies Sony's first consumer HD camcorder is expected to arrive in the U.S. soon. \nIs this a piece of news regarding world politics, sports, business, or science and technology?   Science and technology.", 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.12655246257781982, 'line_break_cnt': 1, 'o_i_ratio': 0.112, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['新闻总结', '相似推荐', '信息检索', '格式输出', '多语言问答', '解释', '定义解释', '总结摘要', '社交媒体', '多选题'], 'topic_prob': [0.46655476093292236, 0.3960840702056885, 0.3933975100517273, 0.3863736689090729, 0.3845677971839905, 0.3839832544326782, 0.373807817697525, 0.3733300268650055, 0.36613044142723083, 0.3613430857658386], 'instag': '["technology", "news", "product", "market"]\n', 'reward': -2.830723762512207, 'deita_quality': 2.1653976061734284, 'hallucination': 0.772917628288269, 'rerank': 0.4724486768245697}
# {'instruction': 'Please a tragic scene outside town ruins with a monument and a square.', 'input': '', 'output': 'The once bustling square now laid in ruins, with the toppled monument lying in the center of it all. Debris and rubble littered the area, as if the town had been bombed to bits. The air was silent, only the howl of the wind whistled through the broken windows of nearby buildings. A lone figure stumbled through the chaos, tears streaming down their face as they mourned the loss of their once beautiful hometown.', 'text': 'Please a tragic scene outside town ruins with a monument and a square.  The once bustling square now laid in ruins, with the toppled monument lying in the center of it all. Debris and rubble littered the area, as if the town had been bombed to bits. The air was silent, only the howl of the wind whistled through the broken windows of nearby buildings. A lone figure stumbled through the chaos, tears streaming down their face as they mourned the loss of their once beautiful hometown.', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.31251534819602966, 'line_break_cnt': 0, 'o_i_ratio': 5.9, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['角色扮演', '解释', '编故事', '多选题', '格式输出', '文本扩写', '写作风格', '意见参考', '意图分类', '完形填空'], 'topic_prob': [0.39684242010116577, 0.38928163051605225, 0.3823307752609253, 0.37489160895347595, 0.37463444471359253, 0.3675469160079956, 0.36197465658187866, 0.35910874605178833, 0.35874250531196594, 0.3525117337703705], 'instag': '["set description"]\n', 'reward': 0.0313054583966732, 'deita_quality': 2.8474858437330113, 'hallucination': 0.07091554254293442, 'rerank': 0.634642481803894}
# {'instruction': 'Who is the main character in the game ‘Sonic the Hedgehog’ by Evil Angel Studios?', 'input': '', 'output': "Sonic the Hedgehog is the main character in the game 'Sonic the Hedgehog' by Evil Angel Studios.", 'text': "Who is the main character in the game ‘Sonic the Hedgehog’ by Evil Angel Studios?  Sonic the Hedgehog is the main character in the game 'Sonic the Hedgehog' by Evil Angel Studios.", 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.007635400164872408, 'line_break_cnt': 0, 'o_i_ratio': 1.185, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': True, 'qa_pair': False, 'topic_label': ['角色扮演', '写作风格', '解释', '格式输出', '编故事', '定义解释', '算法', '多选题', '对比分析', '指代消解'], 'topic_prob': [0.34020012617111206, 0.3270672559738159, 0.30585604906082153, 0.284379780292511, 0.2795465290546417, 0.27495548129081726, 0.27239304780960083, 0.2514551281929016, 0.24865350127220154, 0.24802125990390778], 'instag': '["information request"]\n', 'reward': -0.5492842197418213, 'deita_quality': 2.1464820781434355, 'hallucination': 0.871118426322937, 'rerank': 0.6354279518127441}
# {'instruction': "US guard 'stomped' on Iraqis A colleague testifies against the woman pictured in photos from Iraq's Abu Ghraib prison, Pte Lynndie England. \nIs this a piece of news regarding world politics, sports, business, or science and technology? ", 'input': '', 'output': 'World politics.', 'text': "US guard 'stomped' on Iraqis A colleague testifies against the woman pictured in photos from Iraq's Abu Ghraib prison, Pte Lynndie England. \nIs this a piece of news regarding world politics, sports, business, or science and technology?   World politics.", 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.0023264833725988865, 'line_break_cnt': 1, 'o_i_ratio': 0.064, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['新闻总结', '多语言问答', '信息检索', '解释', '事实求证', '拼写和语法检查', '社交媒体', '标题生成', '语种识别', '定义解释'], 'topic_prob': [0.4288805425167084, 0.38311097025871277, 0.37899497151374817, 0.3755231499671936, 0.3710225224494934, 0.3656373620033264, 0.35770824551582336, 0.35310399532318115, 0.35279422998428345, 0.35277366638183594], 'instag': '["news inquiry"]\n', 'reward': -2.9331114292144775, 'deita_quality': 2.1022631483574514, 'hallucination': 0.32208672165870667, 'rerank': 0.4789266884326935}
# {'instruction': 'MSN Spaces reaction Microsoft blogger Robert Scoble has an exhaustive roundup of the reaction to the new MSN Spaces Web publishing and blogging tool, plus a link to a video interview of the MSN Spaces development team on Microsoft #39;s Channel 9 site. \nIs this a piece of news regarding world politics, sports, business, or science and technology? ', 'input': '', 'output': 'science and technology', 'text': 'MSN Spaces reaction Microsoft blogger Robert Scoble has an exhaustive roundup of the reaction to the new MSN Spaces Web publishing and blogging tool, plus a link to a video interview of the MSN Spaces development team on Microsoft #39;s Channel 9 site. \nIs this a piece of news regarding world politics, sports, business, or science and technology?   science and technology', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.04974737763404846, 'line_break_cnt': 1, 'o_i_ratio': 0.063, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['社交媒体', '新闻总结', '相似推荐', '写作风格', '内容创作', '信息检索', '文本扩写', '多语言问答', '写作辅助', '产品推荐'], 'topic_prob': [0.5041893720626831, 0.44377776980400085, 0.43235722184181213, 0.42510750889778137, 0.4145118296146393, 0.414320170879364, 0.4022460877895355, 0.39920634031295776, 0.39269763231277466, 0.3924217224121094], 'instag': '["news", "technology", "business", "sport", "science and technology"]\n', 'reward': -2.3381383419036865, 'deita_quality': 2.2880584638551227, 'hallucination': 0.6062507629394531, 'rerank': 0.4791432321071625}
# {'instruction': 'EBay ups Internet Auction stake SAN FRANCISCO (CBS.MW) -- EBay said late Tuesday it has agreed to buy 3 million shares of Korea #39;s Internet Auction for \\$325 million in cash. \nIs this a piece of news regarding world politics, sports, business, or science and technology? ', 'input': '', 'output': 'Business', 'text': 'EBay ups Internet Auction stake SAN FRANCISCO (CBS.MW) -- EBay said late Tuesday it has agreed to buy 3 million shares of Korea #39;s Internet Auction for \\$325 million in cash. \nIs this a piece of news regarding world politics, sports, business, or science and technology?   Business', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.0003133330028504133, 'line_break_cnt': 1, 'o_i_ratio': 0.029, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['新闻总结', '社交媒体', '关键词提取', '信息检索', '问答系统', '数据操作', '产品推荐', '信息抽取', '问题解决', '内容创作'], 'topic_prob': [0.388438880443573, 0.3818897306919098, 0.37767714262008667, 0.3666818141937256, 0.35918301343917847, 0.3504953384399414, 0.34336984157562256, 0.34228515625, 0.3402283787727356, 0.3351377248764038], 'instag': '["business news"]\n', 'reward': -2.073408365249634, 'deita_quality': 2.594361651548752, 'hallucination': 0.952101469039917, 'rerank': 0.3275134563446045}
# {'instruction': 'What is the meaning of the Chinese character ‘’?', 'input': '', 'output': 'Sorry, as an AI language model, I am not able to understand or visually see the Chinese character being referred to. Can you provide more context or describe the character in detail?', 'text': 'What is the meaning of the Chinese character ‘’?  Sorry, as an AI language model, I am not able to understand or visually see the Chinese character being referred to. Can you provide more context or describe the character in detail?', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.15523840487003326, 'line_break_cnt': 0, 'o_i_ratio': 3.792, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': True, 'qa_pair': False, 'topic_label': ['解释', '定义解释', '写作风格', '对比分析', '多语言问答', '角色扮演', '阅读理解', '句法分析', '语种识别', '成语填空'], 'topic_prob': [0.5254421830177307, 0.4869495928287506, 0.3831872344017029, 0.3792252540588379, 0.3784298300743103, 0.3744935691356659, 0.36650681495666504, 0.3577510118484497, 0.3573751747608185, 0.35554027557373047], 'instag': '["language learning", "information retrieval"]\n', 'reward': -2.2311463356018066, 'deita_quality': 2.0885434608571813, 'hallucination': 0.2812740206718445, 'rerank': 0.6127597689628601}
# {'instruction': 'Generate for a dark scene inside a temple with a flint slab, arch, and wood.', 'input': '', 'output': "As I enter the temple, the room is pitch black. The only source of light comes from the flickering torches that are mounted on the walls. As I make my way through the darkness, I feel the cold, hard surface of a flint slab beneath my feet. Looking up, I can just barely make out the arch that spans across the room. It's made of weathered stone and looks as though it has been standing for centuries. As I move further into the temple, the sound of my footsteps echo off the walls. Then I begin to smell the scent of burning wood. It grows stronger until I reach a room with a large fire pit in the center. The flames cast flickering shadows over the walls, illuminating the dark room. I can see a group of robed figures standing around a large wooden altar. As I watch, they begin some sort of ceremony, chanting and bowing their heads in unison.", 'text': "Generate for a dark scene inside a temple with a flint slab, arch, and wood.  As I enter the temple, the room is pitch black. The only source of light comes from the flickering torches that are mounted on the walls. As I make my way through the darkness, I feel the cold, hard surface of a flint slab beneath my feet. Looking up, I can just barely make out the arch that spans across the room. It's made of weathered stone and looks as though it has been standing for centuries. As I move further into the temple, the sound of my footsteps echo off the walls. Then I begin to smell the scent of burning wood. It grows stronger until I reach a room with a large fire pit in the center. The flames cast flickering shadows over the walls, illuminating the dark room. I can see a group of robed figures standing around a large wooden altar. As I watch, they begin some sort of ceremony, chanting and bowing their heads in unison.", 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.18146006762981415, 'line_break_cnt': 0, 'o_i_ratio': 11.145, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['文本蕴含', '解释', '编故事', '角色扮演', '内容创作', '摘要生成', '写作风格', '多选题', '指代消解', '格式输出'], 'topic_prob': [0.43377548456192017, 0.41680535674095154, 0.41676628589630127, 0.4074101746082306, 0.38893187046051025, 0.38761022686958313, 0.3876066207885742, 0.3848475515842438, 0.38347047567367554, 0.38122326135635376], 'instag': '["set description"]\n', 'reward': 0.2768360376358032, 'deita_quality': 3.0816138059399236, 'hallucination': 0.2131505012512207, 'rerank': 0.7673813104629517}
# {'instruction': 'MSN Music launch tomorrow p2pnet.net News:- Apple #39;s pre-eminence in the corporate online music retail market is about to be seriously threatened. Slightly more than a year ago, Bill and the Boyz said they were planning to develop something similar to Apple #39;s iTunes - only better. \nIs this a piece of news regarding world politics, sports, business, or science and technology? ', 'input': '', 'output': 'business', 'text': 'MSN Music launch tomorrow p2pnet.net News:- Apple #39;s pre-eminence in the corporate online music retail market is about to be seriously threatened. Slightly more than a year ago, Bill and the Boyz said they were planning to develop something similar to Apple #39;s iTunes - only better. \nIs this a piece of news regarding world politics, sports, business, or science and technology?   business', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.0003862568992190063, 'line_break_cnt': 1, 'o_i_ratio': 0.021, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['社交媒体', '新闻总结', '产品推荐', '相似推荐', '总结摘要', '内容创作', '软件开发', '信息检索', '市场策略', '标题生成'], 'topic_prob': [0.4463665187358856, 0.4418356418609619, 0.39445868134498596, 0.3698383569717407, 0.36399564146995544, 0.3529028296470642, 0.3495206832885742, 0.3490075170993805, 0.3485282063484192, 0.3472946286201477], 'instag': '["news inquiry"]\n', 'reward': -3.4661102294921875, 'deita_quality': 2.3019040329290874, 'hallucination': 0.9817665219306946, 'rerank': 0.3729220926761627}
# {'instruction': 'Please generate a enchanting scene inside of a medieval guild with a carpet, candelabras, and a floor.', 'input': '', 'output': 'The guild hall was aglow with the warm light of dozens of candelabras, their flames flickering gently in the still air. A plush carpet, deep green in color, stretched out from the entrance to the far end of the room, where a raised platform was situated. The walls were adorned with tapestries depicting scenes of knights and dragons, adding to the feeling of enchantment that permeated the air. The floor was made of intricately patterned tiles, each one reflecting the light from the candles above. It was a magical sight, one that would surely inspire awe in any visitor who entered.', 'text': 'Please generate a enchanting scene inside of a medieval guild with a carpet, candelabras, and a floor.  The guild hall was aglow with the warm light of dozens of candelabras, their flames flickering gently in the still air. A plush carpet, deep green in color, stretched out from the entrance to the far end of the room, where a raised platform was situated. The walls were adorned with tapestries depicting scenes of knights and dragons, adding to the feeling of enchantment that permeated the air. The floor was made of intricately patterned tiles, each one reflecting the light from the candles above. It was a magical sight, one that would surely inspire awe in any visitor who entered.', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.2786219120025635, 'line_break_cnt': 0, 'o_i_ratio': 5.745, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['编故事', '角色扮演', '文本蕴含', '解释', '格式输出', '摘要生成', '文本生成', '句子改写', '内容创作', '表格生成'], 'topic_prob': [0.39596906304359436, 0.3957517743110657, 0.39087948203086853, 0.38943928480148315, 0.3863620460033417, 0.3751610517501831, 0.37286651134490967, 0.35994452238082886, 0.3593447208404541, 0.3582722544670105], 'instag': '["set description"]\n', 'reward': -0.17898865044116974, 'deita_quality': 3.754021089162052, 'hallucination': 0.5316367745399475, 'rerank': 0.7549391984939575}
# {'instruction': 'Make a spooky scene inside of a medieval passageway with gouge marks on the floor.', 'input': '', 'output': "As you walk down the narrow passageway, the flickering torchlight casts eerie shadows on the rough stone walls. Gouge marks on the floor lead the way, hinting at some gruesome event that occurred long ago. You hear strange whispers and whispers echo through the corridor, sending shivers down your spine. Suddenly, a gust of cold wind rushes past you, extinguishing the torches and plunging you into total darkness. You can't help but feel that something is watching you from the darkness, waiting to strike at any moment.", 'text': "Make a spooky scene inside of a medieval passageway with gouge marks on the floor.  As you walk down the narrow passageway, the flickering torchlight casts eerie shadows on the rough stone walls. Gouge marks on the floor lead the way, hinting at some gruesome event that occurred long ago. You hear strange whispers and whispers echo through the corridor, sending shivers down your spine. Suddenly, a gust of cold wind rushes past you, extinguishing the torches and plunging you into total darkness. You can't help but feel that something is watching you from the darkness, waiting to strike at any moment.", 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.1995040625333786, 'line_break_cnt': 0, 'o_i_ratio': 6.366, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['编故事', '解释', '摘要生成', '写作风格', '内容创作', '角色扮演', '格式输出', '句子改写', '文本蕴含', '创造性写作'], 'topic_prob': [0.45062434673309326, 0.4428049325942993, 0.4315008819103241, 0.42353081703186035, 0.42287957668304443, 0.4153875708580017, 0.4113992154598236, 0.4103994369506836, 0.40901362895965576, 0.4077567160129547], 'instag': '["scene creation", "artistic direction", "spelling and grammar check"]\n', 'reward': 1.4251295328140259, 'deita_quality': 3.215899942399119, 'hallucination': 0.20058824121952057, 'rerank': 0.7146759033203125}
# {'instruction': 'Stargazers Enjoy Total Lunar Eclipse The moon is partially covered by the shadow of the earth at approximately 9:14 pm EDT, as seen from Archer, Fla., Wednesday, Oct. 27, 2004. \nIs this a piece of news regarding world politics, sports, business, or science and technology? ', 'input': '', 'output': 'science and technology', 'text': 'Stargazers Enjoy Total Lunar Eclipse The moon is partially covered by the shadow of the earth at approximately 9:14 pm EDT, as seen from Archer, Fla., Wednesday, Oct. 27, 2004. \nIs this a piece of news regarding world politics, sports, business, or science and technology?   science and technology', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.3747895658016205, 'line_break_cnt': 1, 'o_i_ratio': 0.081, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['新闻总结', '总结摘要', '社交媒体', '解释', '定义解释', '摘要生成', '文本蕴含', '多语言问答', '相似推荐', '意见参考'], 'topic_prob': [0.4486587345600128, 0.383524090051651, 0.3620225191116333, 0.36086639761924744, 0.3465729057788849, 0.33726853132247925, 0.33098822832107544, 0.32911592721939087, 0.32790493965148926, 0.3278469145298004], 'instag': '["information request"]\n', 'reward': -3.104412794113159, 'deita_quality': 2.3858781213384646, 'hallucination': 0.7711945176124573, 'rerank': 0.48629865050315857}
# ...
# {'instruction': "iBeam adds laser pointer, flashlight to iPod (MacCentral) MacCentral - Griffin Technology Inc. on Monday unveiled the iBeam, a new flashlight and laser pointer combination designed to work as a snap-on package for iPods and iPod minis. The flashlight and laser pointer are two separate devices that feature protective caps and can be clipped on to a keychain when not in use. The devices plug in to the iPod's headphone jack. The package will cost US #36;19.99 when it ships by the end of October. \nIs this a piece of news regarding world politics, sports, business, or science and technology? ", 'input': '', 'output': 'Science and technology.', 'text': "iBeam adds laser pointer, flashlight to iPod (MacCentral) MacCentral - Griffin Technology Inc. on Monday unveiled the iBeam, a new flashlight and laser pointer combination designed to work as a snap-on package for iPods and iPod minis. The flashlight and laser pointer are two separate devices that feature protective caps and can be clipped on to a keychain when not in use. The devices plug in to the iPod's headphone jack. The package will cost US #36;19.99 when it ships by the end of October. \nIs this a piece of news regarding world politics, sports, business, or science and technology?   Science and technology.", 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.043020691722631454, 'line_break_cnt': 1, 'o_i_ratio': 0.039, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['产品推荐', '相似推荐', '格式输出', '工具使用', '算法', '关键词提取', '标签生成', '数据操作', '解释', '内容创作'], 'topic_prob': [0.4051605761051178, 0.36662232875823975, 0.3511641025543213, 0.35106247663497925, 0.3433770537376404, 0.3433734178543091, 0.32293829321861267, 0.32181882858276367, 0.3186749517917633, 0.3158038556575775], 'instag': '["product information", "price"]\n', 'reward': -0.7556695938110352, 'deita_quality': 2.2151658041566407, 'hallucination': 0.5148928761482239, 'rerank': 0.48201480507850647}
# {'instruction': 'Generate a suspenseful scene outside the stockade with hard-packed ground and massive gates.', 'input': '', 'output': 'The darkness had settled in, casting eerie shadows across the hard-packed ground outside the stockade walls. The massive gates loomed before them, creaking slowly in the wind. With a deep breath, they stepped forward, inching closer to the imposing entrance. A faint rustling broke the stillness, causing them to freeze in place, heartbeats pounding in their ears. Was it just the wind, or something more sinister lurking in the shadows?', 'text': 'Generate a suspenseful scene outside the stockade with hard-packed ground and massive gates.  The darkness had settled in, casting eerie shadows across the hard-packed ground outside the stockade walls. The massive gates loomed before them, creaking slowly in the wind. With a deep breath, they stepped forward, inching closer to the imposing entrance. A faint rustling broke the stillness, causing them to freeze in place, heartbeats pounding in their ears. Was it just the wind, or something more sinister lurking in the shadows?', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.5533860921859741, 'line_break_cnt': 0, 'o_i_ratio': 4.75, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['编故事', '摘要生成', '格式输出', '解释', '输入处理', '指代消解', '代码生成', '文本蕴含', '多选题', '算法'], 'topic_prob': [0.42349833250045776, 0.4223461151123047, 0.41801273822784424, 0.4136268198490143, 0.40388673543930054, 0.4030144214630127, 0.40037500858306885, 0.3971902132034302, 0.3960181474685669, 0.394381582736969], 'instag': '["scene description", "set description", "character description", "action description", "suspense"]\n', 'reward': 0.956716775894165, 'deita_quality': 2.857326027980889, 'hallucination': 0.6686141490936279, 'rerank': 0.7762234210968018}
# {'instruction': 'Inflation shows surprise fall The inflation rate unexpectedly fell further below its 2.0 percent government-set target in August as clothing and footwear retailers raised prices by less than a year ago, official data shows. \nIs this a piece of news regarding world politics, sports, business, or science and technology? ', 'input': '', 'output': 'business', 'text': 'Inflation shows surprise fall The inflation rate unexpectedly fell further below its 2.0 percent government-set target in August as clothing and footwear retailers raised prices by less than a year ago, official data shows. \nIs this a piece of news regarding world politics, sports, business, or science and technology?   business', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.003362494520843029, 'line_break_cnt': 1, 'o_i_ratio': 0.025, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['新闻总结', '市场策略', '数据分析', '对比分析', '定义解释', '标题生成', '数据处理', '解释', '数据操作', '句法分析'], 'topic_prob': [0.45171985030174255, 0.4141782820224762, 0.41398510336875916, 0.4032127559185028, 0.38568684458732605, 0.3800854980945587, 0.370809942483902, 0.3702937960624695, 0.36805981397628784, 0.36701565980911255], 'instag': '["news analysis"]\n', 'reward': -1.4896883964538574, 'deita_quality': 2.527144089218382, 'hallucination': 0.8456125855445862, 'rerank': 0.399400919675827}
# {'instruction': 'What label best describes this news article?\n\'Grand Theft Auto\' Seen Breaking Games Sales Record (Reuters) Reuters - When the violent video game "Grand\\Theft Auto: San Andreas" hits stores on Tuesday, its sales\\could eclipse Hollywood\'s most successful films, even as it\\draws the ire of critics. ', 'input': '', 'output': 'Entertainment / Technology', 'text': 'What label best describes this news article?\n\'Grand Theft Auto\' Seen Breaking Games Sales Record (Reuters) Reuters - When the violent video game "Grand\\Theft Auto: San Andreas" hits stores on Tuesday, its sales\\could eclipse Hollywood\'s most successful films, even as it\\draws the ire of critics.   Entertainment / Technology', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.011557413265109062, 'line_break_cnt': 1, 'o_i_ratio': 0.088, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': True, 'qa_pair': False, 'topic_label': ['新闻总结', '相似推荐', '总结摘要', '格式输出', '产品推荐', '对比分析', '写作风格', '社交媒体', '算法', '错误处理'], 'topic_prob': [0.37298187613487244, 0.3279825747013092, 0.3009811043739319, 0.29951024055480957, 0.2975899577140808, 0.29579782485961914, 0.294415682554245, 0.28920572996139526, 0.27853238582611084, 0.27413633465766907], 'instag': '["news analysis", "video game"]\n', 'reward': -0.6396799087524414, 'deita_quality': 3.0243445062460523, 'hallucination': 0.2594415247440338, 'rerank': 0.4227130711078644}
# {'instruction': 'Growing up with Little E #39; TALLADEGA -- Dale Earnhardt Jr. begins his last week at age 29 today, and  quot;Little E quot; is laying plans for the future. The most immediate include a strategy for today #39;s EA Sports 500 at Talladega Superspeedway  \nIs this a piece of news regarding world politics, sports, business, or science and technology? ', 'input': '', 'output': 'Sports.', 'text': 'Growing up with Little E #39; TALLADEGA -- Dale Earnhardt Jr. begins his last week at age 29 today, and  quot;Little E quot; is laying plans for the future. The most immediate include a strategy for today #39;s EA Sports 500 at Talladega Superspeedway  \nIs this a piece of news regarding world politics, sports, business, or science and technology?   Sports.', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.04411303997039795, 'line_break_cnt': 1, 'o_i_ratio': 0.02, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['新闻总结', '总结摘要', '写作风格', '解释', '任务规划', '多语言问答', '摘要生成', '编故事', '算法', '标题生成'], 'topic_prob': [0.41222718358039856, 0.3857457935810089, 0.3719267249107361, 0.3695642352104187, 0.36818957328796387, 0.36317989230155945, 0.3555157780647278, 0.35138413310050964, 0.3467470407485962, 0.34339606761932373], 'instag': '["sport", "business", "science and technology"]\n', 'reward': -3.172902822494507, 'deita_quality': 2.188478504816885, 'hallucination': 0.9044869542121887, 'rerank': 0.408183753490448}
# {'instruction': 'Barnes   Noble a Hit in 2Q The bookseller beats core earnings estimates and raises its full-year guidance. \nIs this a piece of news regarding world politics, sports, business, or science and technology? ', 'input': '', 'output': 'business', 'text': 'Barnes   Noble a Hit in 2Q The bookseller beats core earnings estimates and raises its full-year guidance. \nIs this a piece of news regarding world politics, sports, business, or science and technology?   business', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.0005688217934221029, 'line_break_cnt': 1, 'o_i_ratio': 0.039, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['新闻总结', '写作风格', '阅读理解', '多选题', '总结摘要', '关键词提取', '解释', '相似推荐', '内容创作', '完形填空'], 'topic_prob': [0.472683310508728, 0.4162847101688385, 0.40845105051994324, 0.4069846570491791, 0.406858891248703, 0.40126222372055054, 0.3971765339374542, 0.3966295123100281, 0.3961581289768219, 0.3932655453681946], 'instag': '["business news"]\n', 'reward': -1.952033519744873, 'deita_quality': 2.474144298630563, 'hallucination': 0.977242112159729, 'rerank': 0.35803747177124023}
# {'instruction': 'Olympics-Federer #39;s Olympic dream shattered twice over ATHENS, Aug 17 (Reuters) - World number one Roger Federer #39;s top target for the year -- an Olympic tennis gold medal -- was taken away from him in a  quot;terrible day quot; on Tuesday.  \nIs this a piece of news regarding world politics, sports, business, or science and technology? ', 'input': '', 'output': 'Sports.', 'text': 'Olympics-Federer #39;s Olympic dream shattered twice over ATHENS, Aug 17 (Reuters) - World number one Roger Federer #39;s top target for the year -- an Olympic tennis gold medal -- was taken away from him in a  quot;terrible day quot; on Tuesday.  \nIs this a piece of news regarding world politics, sports, business, or science and technology?   Sports.', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.025654179975390434, 'line_break_cnt': 1, 'o_i_ratio': 0.02, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['新闻总结', '标题生成', '相似推荐', '多选题', '任务规划', '总结摘要', '句子改写', '写作风格', '编程语言', '关键词提取'], 'topic_prob': [0.3665159344673157, 0.323628693819046, 0.3160702586174011, 0.30802127718925476, 0.3071093261241913, 0.30700263381004333, 0.3052749037742615, 0.3039972484111786, 0.3012063503265381, 0.29400134086608887], 'instag': '["sport news"]\n', 'reward': -2.1251089572906494, 'deita_quality': 2.134410671680598, 'hallucination': 0.7291476726531982, 'rerank': 0.40846171975135803}
# {'instruction': 'A bathroom has 10 6 inch tiles along its width and 20 6 inch tiles along its length. What is the square footage of the bathroom?', 'input': '', 'output': 'To find the square footage of the bathroom, we need to first find the area in square inches. The width of the bathroom is 10 tiles, each of which is 6 inches, so the width is 10 * 6 = 60 inches. The length of the bathroom is 20 tiles, each of which is 6 inches, so the length is 20 * 6 = 120 inches. Therefore, the area in square inches is 60 * 120 = 7200 square inches. To convert this to square footage, we divide by 144 (since there are 144 square inches in one square foot): 7200 / 144 = 50 square feet. So the square footage of the bathroom is 50 square feet.', 'text': 'A bathroom has 10 6 inch tiles along its width and 20 6 inch tiles along its length. What is the square footage of the bathroom?  To find the square footage of the bathroom, we need to first find the area in square inches. The width of the bathroom is 10 tiles, each of which is 6 inches, so the width is 10 * 6 = 60 inches. The length of the bathroom is 20 tiles, each of which is 6 inches, so the length is 20 * 6 = 120 inches. Therefore, the area in square inches is 60 * 120 = 7200 square inches. To convert this to square footage, we divide by 144 (since there are 144 square inches in one square foot): 7200 / 144 = 50 square feet. So the square footage of the bathroom is 50 square feet.', 'meta': {'Dataset': 'GPT4all', 'Gen': 'COL', 'IFT': 'True', 'Lang': 'EN', 'Multi-round Dialog': 'False', 'Preference': 'False', 'SFT': 'True', 'Task': 'MT', 'original_path': 'Alpaca-CoT/GPT4all/gpt4all.json'}, 'html_block': False, 'code_detect': False, 'math_score': 0.5293242931365967, 'line_break_cnt': 0, 'o_i_ratio': 4.406, 'sql_detect_cnt': 0, 'Article_contain': False, 'abcd_options': False, 'seven_ask': False, 'qa_pair': False, 'topic_label': ['解释', '多选题', '定义解释', '算法', '多语言问答', '对比分析', '完形填空', '常识问答', '数学计算', '文本扩写'], 'topic_prob': [0.3915031850337982, 0.37932199239730835, 0.37590712308883667, 0.3757956027984619, 0.36779600381851196, 0.3626563549041748, 0.3586442768573761, 0.35083988308906555, 0.3503658175468445, 0.3216972053050995], 'instag': '["mathematics", "measurement", "unit conversion", "problem solve"]\n', 'reward': 2.0387983322143555, 'deita_quality': 4.799507342825564, 'hallucination': 0.6370508074760437, 'rerank': 0.7810541391372681}
# end_sign_cnt 625
# ghost_cnt 312
# generate_nonsense_count 32243

# %%
# 故事续写', '编故事
